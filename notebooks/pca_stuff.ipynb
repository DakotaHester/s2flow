# %%
from s2flow.data.pca import load_pca

# %%
pca = load_pca({})['pca']
print(pca.explained_variance_ratio_)
# Out:
# [0.78550156 0.19686968 0.01607761]

# %%
pca.explained_variance_ratio_.sum()
# Out:
# np.float64(0.9984488472665832)

# %%
print(pca.n_samples_seen_)
# Out:
# 7516192768

# %%
# show ALL attributes of pca
for attr in dir(pca):
    # if not attr.startswith("_"):
    print(attr, getattr(pca, attr))
# Out:
# _IncrementalPCA__metadata_request__partial_fit {'check_input': '$UNUSED$'}
# __abstractmethods__ frozenset()
# __annotations__ {'_parameter_constraints': <class 'dict'>}
# __class__ <class 'sklearn.decomposition._incremental_pca.IncrementalPCA'>
# __delattr__ <method-wrapper '__delattr__' of IncrementalPCA object at 0x12061fe30>
# __dict__ {'n_components': 3, 'whiten': False, 'copy': True, 'batch_size': None, 'n_features_in_': 4, 'components_': array([[ 0.53648623,  0.5598765 ,  0.55107636,  0.30827857],
#        [-0.27612922, -0.11269297, -0.14448903,  0.94349132],
# ...
